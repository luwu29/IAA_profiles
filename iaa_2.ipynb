# %% [markdown]
# # Install packages and import files

# %%
import nltk, re, pprint
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
import pandas as pd
import numpy as np



from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.datasets import fetch_20newsgroups
from sklearn.decomposition import NMF, LatentDirichletAllocation

import seaborn as sns
import matplotlib as plt

# %%
profile=pd.read_excel('profiles_csv_updated_20191011.xlsx')

# %%
profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 7 columns):
# Name                                     118 non-null object
# Gender                                   118 non-null object
# All But Last Paragraph (professional)    118 non-null object
#  Last Paragraph (personal)               117 non-null object
# Cohort                                   118 non-null object
# International                            117 non-null float64
# full                                     118 non-null object
# dtypes: float64(1), object(6)
# memory usage: 6.5+ KB

# %%
#set name to be the index
profile.set_index('Name', inplace=True)

# %%
#a=profile.index.unique()

# %% [markdown]
# # First round of text cleaning

# %%
import re
import string

# %%
porter = nltk.stem.porter.PorterStemmer()

def clean_text_round1(text):
    #remove puncuations and breakers
    text=re.sub('\t',' ', text)
    text=re.sub('[%s]' % re.escape( string.punctuation ), '', text)
    text=re.sub('\n', ' ',text)
    text=porter.stem(text)
    return text

# %%
round1=lambda x:clean_text_round1(x)

# %%
#apply to the dataframe
data_clean=pd.DataFrame(profile.full.apply(round1))

# %%
data_clean.full.tail(50)
# Out:
# Name
# Travis Noftle             having almost a decade of experience in invest...
# Urbain Nounagnon          turning        challenges        into        o...
# Krishna Patel             as an avid  butterfly enthusiast  throughout  ...
# Payal Patel               payal is an ambitious adventurer who enjoys ex...
# Samir Patel               one of  the most important  ties samir has  to...
# Urmila Patil              urmila’s  best  qualities are analytical  thin...
# Jackson Perry             team  is  everything  to  jackson  over  the  ...
# Rachel Powell             after  many  rounds  of  experiments  rachel  ...
# Alexander Preiss          sandy  thrives  at  the  intersection  of  dat...
# Sunny\tQin                as  a  product  of  entrepreneurial  parents  ...
# Lahari Revuri             lahari  explores  the  world  through  the  le...
# Jonathan Rice             studying  human  population  genetics  for  th...
# Benjamin Roberts          growing        up        in        a        sm...
# Basil Rodts               basil will “try anything once” this life motto...
# Kyrsten Rudock            whether  pouring  passion  into  a  clarinet  ...
# Burton Scott Rudolph\n    impact        motivates        burton        w...
# Charlie Ruff\n            charlie’s love for sports statistics led him t...
# Sameen Salam              from a  very  young age sameen identified and ...
# Samantha Sassorossi       data  science is  like  a  puzzle  where  all ...
# Cassidy Sater             from a young age cassidy was always seen solvi...
# Noah Woessner Sayre       passion  and  dedication  are  fundamental  co...
# Sam Scarpino              before arriving in the field of analytics sam’...
# Austin Seals              after conducting research that modeled the per...
# Keyur Shah                an avid fan of the game of cricket keyur used ...
# Sufyan Shahin             sufyan  has  spent  the  past  decade  helping...
# Mehak Shamdasani          since childhood mehak has been drawn to patter...
# Stephen Slogar\n          stephen’s passion  for mathematics goes  back ...
# Jiin Son                  jiin uncovered her interest in data while work...
# Paige Spell               don’t be afraid  to  fail paige applies  this ...
# Nick Sterling             is it possible to forecast a coastal housing m...
# Ben Sullivan              ben found an interest in analytics during his ...
# Heqing Sun                heqing’s eagerness  to learn quantitative appr...
# Yao Sun                   intrigued by  the knowledge hidden behind an a...
# Shannon Tart              an innate curiosity a passion for solving comp...
# Reema Thakkar             growing up as a child of two indian immigrants...
# Chelsea Thomas            chelsea first fell in love with data analysis ...
# Jason Thompson\n          jason  fell  in  love  with  numbers  at  an  ...
# Wesley Thompson           at the beginning of his ap statistics course w...
# Cathy Tran                cathy  positively impacts every  place  she jo...
# Khoi Minh Tran            behind every success  there is a story  to be ...
# Faith Turner              from a young age faith has always been a creat...
# Travis M. Walker          a veteran of the united states navy and specia...
# Meghan Weber              meghan’s ambitious spirit has always driven he...
# Ryan Weisner              making        a        difference        this ...
# Samantha  Widman          teamwork is a foundation skill for samantha at...
# Sarah Wotus               sarah has always been passionate about health ...
# Lu Wu                     lu crossed paths with data analytics when she ...
# Chesaney Wyse             with an analytical mindset and fortitude beyon...
# Sharon Yao                the first time sharon influenced changes on a ...
# Michael Zabawa            believing that knowledge backed with data is m...
# Name: full, dtype: object

# %% [markdown]
# # Document-Term Matrix

# %%
cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(data_clean.full)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_dtm.index = data_clean.index
data_dtm
# Out:
#                           10  100  10000  1012  10k  11  1200  13  140page  \
# Name
# Shiraz Ahmed               0    0      0     0    0   0     0   0        0
# Emily Ammons               0    0      0     0    0   0     0   0        0
# David Andexler             0    0      0     0    0   0     0   0        0
# Ryan Ankersen              0    0      0     0    0   0     0   0        0
# Rivers Baker               0    0      0     0    0   0     0   0        0
# Robert Bayer               1    0      0     0    0   0     0   0        0
# Alison Berger              0    0      0     0    0   0     0   0        0
# Marshall Bradley           0    0      0     0    0   0     0   0        0
# Price Burnett              0    0      0     0    0   0     0   0        0
# Jackson Cabell             1    0      0     0    0   0     0   0        0
# Ellie Caldwell             0    0      0     0    0   0     0   0        0
# Patrick Campbell           0    0      0     0    0   0     0   0        0
# Dominick Carbone           0    0      0     0    0   0     0   0        0
# Shao Chen                  0    0      0     0    0   0     0   0        0
# Yuting (Crystal) Cheng     0    0      0     0    0   0     0   0        0
# Kyle Clapper               0    0      0     0    0   0     0   0        0
# Grant Clark                0    0      0     0    0   0     0   0        0
# Brittany Elizabeth Cody    0    0      0     0    0   0     0   0        0
# Jess Conner                0    0      0     0    0   0     0   0        0
# Walter Creech              0    0      0     0    0   0     0   0        0
# Emmanuel Daramola          0    0      0     0    0   0     0   0        0
# Ellen Davis                0    0      0     0    0   0     0   0        0
# Supreet Sudhir Deshpande   0    0      0     0    0   0     0   0        0
# Adria Dortignacq           0    0      0     0    0   0     0   0        0
# Trevor Edge                0    0      0     0    0   0     0   0        0
# William Elmore             0    0      0     0    0   0     0   0        0
# Abla Elsergany             0    0      0     0    0   0     0   0        0
# Samantha Everett           0    0      0     0    0   0     0   0        0
# Maxwell Fairbairn          0    0      0     0    0   0     0   0        0
# Andrew Francis             0    0      0     0    0   0     0   0        0
# ...                       ..  ...    ...   ...  ...  ..   ...  ..      ...
# Noah Woessner Sayre        0    0      0     0    0   0     0   0        0
# Sam Scarpino               0    0      0     0    0   0     0   0        0
# Austin Seals               0    0      0     0    0   0     0   0        0
# Keyur Shah                 0    0      0     0    0   0     0   0        0
# Sufyan Shahin              0    0      0     0    0   0     0   0        0
# Mehak Shamdasani           0    0      0     0    0   0     0   0        0
# Stephen Slogar\n           0    0      0     0    0   0     0   0        0
# Jiin Son                   0    0      0     0    0   0     0   0        0
# Paige Spell                0    0      0     0    0   0     0   0        0
# Nick Sterling              0    0      0     0    0   0     0   0        0
# Ben Sullivan               0    0      0     0    0   0     0   1        0
# Heqing Sun                 0    0      0     0    0   0     0   0        0
# Yao Sun                    0    0      0     0    0   0     0   0        0
# Shannon Tart               0    0      0     0    0   0     0   0        0
# Reema Thakkar              0    0      0     0    0   0     0   0        0
# Chelsea Thomas             0    0      0     0    0   0     0   0        0
# Jason Thompson\n           0    0      0     0    0   0     0   0        0
# Wesley Thompson            0    0      0     0    0   0     0   0        0
# Cathy Tran                 0    0      0     0    0   0     0   0        0
# Khoi Minh Tran             0    0      0     0    0   0     0   0        0
# Faith Turner               0    0      0     0    0   0     0   0        0
# Travis M. Walker           0    0      0     0    0   0     0   0        0
# Meghan Weber               0    0      0     0    0   0     0   0        0
# Ryan Weisner               0    0      0     0    0   0     0   0        0
# Samantha  Widman           0    0      0     0    0   0     0   0        0
# Sarah Wotus                0    0      0     0    0   0     0   0        0
# Lu Wu                      0    0      0     0    0   0     0   0        0
# Chesaney Wyse              0    0      0     0    0   0     0   0        0
# Sharon Yao                 0    0      0     0    0   0     0   0        0
# Michael Zabawa             0    0      0     0    0   0     0   0        0
#
#                           15  ...  youth  youtube  zach  zeal  zealous  zion  \
# Name                          ...
# Shiraz Ahmed               0  ...      0        0     0     0        0     0
# Emily Ammons               0  ...      0        0     0     0        0     0
# David Andexler             0  ...      0        0     0     0        0     0
# Ryan Ankersen              0  ...      0        0     0     0        0     0
# Rivers Baker               0  ...      0        0     0     0        0     0
# Robert Bayer               0  ...      0        0     0     0        0     0
# Alison Berger              0  ...      0        0     0     0        0     0
# Marshall Bradley           0  ...      0        0     0     0        0     0
# Price Burnett              0  ...      0        0     0     0        0     0
# Jackson Cabell             0  ...      0        0     0     0        0     0
# Ellie Caldwell             0  ...      0        0     0     1        0     0
# Patrick Campbell           0  ...      0        0     0     0        0     0
# Dominick Carbone           0  ...      0        0     0     0        0     0
# Shao Chen                  0  ...      0        0     0     0        0     0
# Yuting (Crystal) Cheng     0  ...      0        0     0     0        0     0
# Kyle Clapper               0  ...      0        0     0     0        0     0
# Grant Clark                0  ...      0        0     0     0        0     0
# Brittany Elizabeth Cody    0  ...      0        0     0     0        0     0
# Jess Conner                0  ...      0        0     0     0        0     0
# Walter Creech              0  ...      0        0     0     0        0     0
# Emmanuel Daramola          0  ...      0        0     0     0        0     0
# Ellen Davis                0  ...      1        0     0     0        0     0
# Supreet Sudhir Deshpande   0  ...      0        0     0     0        0     0
# Adria Dortignacq           0  ...      0        0     0     0        0     0
# Trevor Edge                0  ...      0        0     0     0        0     0
# William Elmore             0  ...      0        0     0     0        0     0
# Abla Elsergany             1  ...      0        0     0     1        0     0
# Samantha Everett           0  ...      0        0     0     0        0     0
# Maxwell Fairbairn          0  ...      0        0     0     0        0     0
# Andrew Francis             0  ...      0        0     0     0        0     0
# ...                       ..  ...    ...      ...   ...   ...      ...   ...
# Noah Woessner Sayre        0  ...      0        0     0     0        0     0
# Sam Scarpino               0  ...      0        0     0     0        0     0
# Austin Seals               0  ...      2        0     0     0        0     0
# Keyur Shah                 0  ...      0        0     0     0        0     0
# Sufyan Shahin              0  ...      0        0     0     0        0     0
# Mehak Shamdasani           0  ...      0        0     0     0        0     0
# Stephen Slogar\n           0  ...      0        0     0     0        0     0
# Jiin Son                   0  ...      0        0     0     0        0     0
# Paige Spell                0  ...      0        0     0     0        0     0
# Nick Sterling              0  ...      0        0     0     0        0     0
# Ben Sullivan               0  ...      0        0     0     0        0     0
# Heqing Sun                 0  ...      0        0     0     0        0     0
# Yao Sun                    1  ...      0        0     0     0        0     0
# Shannon Tart               0  ...      0        0     0     0        0     0
# Reema Thakkar              0  ...      0        0     0     0        0     0
# Chelsea Thomas             0  ...      0        0     0     0        0     0
# Jason Thompson\n           0  ...      1        0     0     0        0     0
# Wesley Thompson            1  ...      0        0     0     0        0     0
# Cathy Tran                 0  ...      0        0     0     0        0     0
# Khoi Minh Tran             0  ...      0        0     0     0        0     0
# Faith Turner               0  ...      0        0     0     0        0     0
# Travis M. Walker           0  ...      0        0     0     0        0     0
# Meghan Weber               0  ...      0        0     0     0        0     0
# Ryan Weisner               0  ...      0        0     0     0        0     0
# Samantha  Widman           0  ...      0        0     0     0        0     0
# Sarah Wotus                0  ...      0        0     0     0        0     1
# Lu Wu                      0  ...      0        0     0     0        0     0
# Chesaney Wyse              0  ...      0        0     0     0        0     0
# Sharon Yao                 1  ...      0        0     0     0        0     0
# Michael Zabawa             0  ...      0        0     0     0        0     0
#
#                           zip  ziplining  zone  zs
# Name
# Shiraz Ahmed                0          0     0   0
# Emily Ammons                0          0     0   0
# David Andexler              0          0     0   0
# Ryan Ankersen               0          0     0   0
# Rivers Baker                0          0     0   0
# Robert Bayer                0          0     0   0
# Alison Berger               0          1     0   0
# Marshall Bradley            0          0     0   0
# Price Burnett               0          0     0   0
# Jackson Cabell              0          0     0   0
# Ellie Caldwell              0          0     0   0
# Patrick Campbell            0          0     0   0
# Dominick Carbone            0          0     0   0
# Shao Chen                   0          0     0   0
# Yuting (Crystal) Cheng      0          0     0   0
# Kyle Clapper                0          0     0   0
# Grant Clark                 0          0     0   0
# Brittany Elizabeth Cody     0          0     0   0
# Jess Conner                 0          0     0   0
# Walter Creech               0          0     0   0
# Emmanuel Daramola           0          0     0   0
# Ellen Davis                 0          0     0   0
# Supreet Sudhir Deshpande    0          0     0   3
# Adria Dortignacq            0          0     0   0
# Trevor Edge                 0          0     0   0
# William Elmore              0          0     0   0
# Abla Elsergany              0          0     0   0
# Samantha Everett            0          0     0   0
# Maxwell Fairbairn           0          0     0   0
# Andrew Francis              0          0     0   0
# ...                       ...        ...   ...  ..
# Noah Woessner Sayre         0          0     0   0
# Sam Scarpino                0          0     0   0
# Austin Seals                0          0     0   0
# Keyur Shah                  0          0     0   0
# Sufyan Shahin               0          0     0   0
# Mehak Shamdasani            0          0     0   0
# Stephen Slogar\n            0          0     0   0
# Jiin Son                    0          0     0   0
# Paige Spell                 0          0     0   0
# Nick Sterling               0          0     0   0
# Ben Sullivan                0          0     0   0
# Heqing Sun                  0          0     0   0
# Yao Sun                     0          0     0   0
# Shannon Tart                0          0     0   0
# Reema Thakkar               0          0     0   0
# Chelsea Thomas              0          0     0   0
# Jason Thompson\n            0          0     0   0
# Wesley Thompson             0          0     0   0
# Cathy Tran                  0          0     0   0
# Khoi Minh Tran              0          0     1   0
# Faith Turner                0          0     0   0
# Travis M. Walker            0          0     0   0
# Meghan Weber                0          0     0   0
# Ryan Weisner                0          0     0   0
# Samantha  Widman            0          0     0   0
# Sarah Wotus                 0          0     0   0
# Lu Wu                       0          0     0   0
# Chesaney Wyse               0          0     1   0
# Sharon Yao                  0          0     0   0
# Michael Zabawa              0          0     0   0
#
# [118 rows x 5084 columns]

# %%
data_dtm.shape
# Out:
# (118, 5084)

# %%
#transpose the dataframe
data = data_dtm.transpose()
data.head()
# Out:
# Name   Shiraz Ahmed  Emily Ammons  David Andexler  Ryan Ankersen  \
# 10                0             0               0              0
# 100               0             0               0              0
# 10000             0             0               0              0
# 1012              0             0               0              0
# 10k               0             0               0              0
#
# Name   Rivers Baker  Robert Bayer  Alison Berger  Marshall Bradley  \
# 10                0             1              0                 0
# 100               0             0              0                 0
# 10000             0             0              0                 0
# 1012              0             0              0                 0
# 10k               0             0              0                 0
#
# Name   Price Burnett  Jackson Cabell  ...  Faith Turner  Travis M. Walker  \
# 10                 0               1  ...             0                 0
# 100                0               0  ...             0                 0
# 10000              0               0  ...             0                 0
# 1012               0               0  ...             0                 0
# 10k                0               0  ...             0                 0
#
# Name   Meghan Weber  Ryan Weisner  Samantha  Widman  Sarah Wotus   Lu Wu  \
# 10                0             0                 0             0      0
# 100               0             0                 0             0      0
# 10000             0             0                 0             0      0
# 1012              0             0                 0             0      0
# 10k               0             0                 0             0      0
#
# Name   Chesaney Wyse   Sharon Yao  Michael Zabawa
# 10                  0           0               0
# 100                 0           0               0
# 10000               0           0               0
# 1012                0           0               0
# 10k                 0           0               0
#
# [5 rows x 118 columns]

# %% [markdown]
# ## find the top 10 words for each person

# %%
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(10)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {'Shiraz Ahmed': [('data', 6),
#   ('shiraz', 4),
#   ('foreign', 2),
#   ('work', 2),
#   ('middle', 2),
#   ('analytics', 2),
#   ('skin', 2),
#   ('discrimination', 2),
#   ('conclusions', 2),
#   ('nations', 2)],
#  'Emily Ammons': [('emily', 8),
#   ('research', 3),
#   ('community', 3),
#   ('native', 3),
#   ('study', 3),
#   ('grass', 3),
#   ('beta', 3),
#   ('communication', 2),
#   ('spatial', 2),
#   ('biology', 2)],
#  'David Andexler': [('david', 5),
#   ('time', 4),
#   ('student', 3),
#   ('organizations', 2),
#   ('marketing', 2),
#   ('position', 2),
#   ('strategies', 2),
#   ('business', 2),
#   ('understanding', 2),
#   ('government', 2)],
#  'Ryan Ankersen': [('ryan', 6),
#   ('new', 4),
#   ('challenges', 3),
#   ('members', 2),
#   ('learn', 2),
#   ('event', 2),
#   ('college', 2),
#   ('team', 2),
#   ('father', 2),
#   ('accepted', 1)],
#  'Rivers Baker': [('rivers', 6),
#   ('business', 5),
#   ('analytics', 4),
#   ('data', 4),
#   ('development', 3),
#   ('collaboration', 2),
#   ('biotechnology', 2),
#   ('team', 2),
#   ('plan', 2),
#   ('solutions', 2)],
#  'Robert Bayer': [('robert', 6),
#   ('working', 4),
#   ('data', 3),
#   ('manufacturing', 3),
#   ('research', 3),
#   ('chemical', 3),
#   ('opportunity', 2),
#   ('time', 2),
#   ('projects', 2),
#   ('work', 2)],
#  'Alison Berger': [('alison', 6),
#   ('analytics', 5),
#   ('team', 4),
#   ('using', 3),
#   ('insights', 3),
#   ('satisfaction', 2),
#   ('disney', 2),
#   ('running', 2),
#   ('data', 2),
#   ('web', 2)],
#  'Marshall Bradley': [('marshall', 7),
#   ('time', 4),
#   ('leading', 3),
#   ('best', 2),
#   ('career', 2),
#   ('south', 2),
#   ('studying', 2),
#   ('research', 2),
#   ('data', 2),
#   ('analytics', 2)],
#  'Price Burnett': [('price', 5),
#   ('role', 2),
#   ('nature', 2),
#   ('supply', 2),
#   ('family', 2),
#   ('chain', 2),
#   ('free', 1),
#   ('algebra', 1),
#   ('active', 1),
#   ('articles', 1)],
#  'Jackson Cabell': [('jackson', 8),
#   ('data', 7),
#   ('analytics', 4),
#   ('nba', 3),
#   ('unc', 2),
#   ('science', 2),
#   ('team', 2),
#   ('statistics', 2),
#   ('earned', 2),
#   ('metlife', 2)],
#  'Ellie Caldwell': [('ellie', 9),
#   ('learning', 3),
#   ('new', 3),
#   ('students', 3),
#   ('team', 3),
#   ('time', 2),
#   ('carolina', 2),
#   ('senior', 2),
#   ('mountains', 2),
#   ('north', 2)],
#  'Patrick Campbell': [('patrick', 8),
#   ('technical', 4),
#   ('financial', 3),
#   ('services', 3),
#   ('experience', 3),
#   ('sas', 3),
#   ('role', 3),
#   ('career', 2),
#   ('capital', 2),
#   ('collaborating', 2)],
#  'Dominick Carbone': [('model', 5),
#   ('dominick', 4),
#   ('actuarial', 3),
#   ('data', 3),
#   ('focused', 3),
#   ('work', 3),
#   ('intern', 3),
#   ('state', 2),
#   ('scholarship', 2),
#   ('enabled', 2)],
#  'Shao Chen': [('shao', 10),
#   ('data', 5),
#   ('research', 4),
#   ('different', 4),
#   ('trading', 2),
#   ('people', 2),
#   ('analyzing', 2),
#   ('exchange', 2),
#   ('product', 2),
#   ('human', 2)],
#  'Yuting (Crystal) Cheng': [('data', 7),
#   ('crystal', 6),
#   ('team', 5),
#   ('skills', 4),
#   ('migration', 3),
#   ('tax', 2),
#   ('cream', 2),
#   ('started', 2),
#   ('cakes', 2),
#   ('cake', 2)],
#  'Kyle Clapper': [('kyle', 9),
#   ('business', 4),
#   ('efficiency', 4),
#   ('rafting', 3),
#   ('analytics', 3),
#   ('school', 2),
#   ('guests', 2),
#   ('project', 2),
#   ('discovered', 2),
#   ('process', 2)],
#  'Grant Clark': [('grant', 6),
#   ('data', 4),
#   ('world', 3),
#   ('lighthouse', 3),
#   ('guild', 3),
#   ('solving', 3),
#   ('tools', 2),
#   ('statistics', 2),
#   ('time', 2),
#   ('analytics', 2)],
#  'Brittany Elizabeth Cody': [('brittany', 5),
#   ('data', 5),
#   ('intelligence', 3),
#   ('public', 3),
#   ('science', 3),
#   ('political', 3),
#   ('legitimacy', 2),
#   ('panel', 2),
#   ('world', 2),
#   ('visualizations', 2)],
#  'Jess Conner': [('jess', 9),
#   ('new', 3),
#   ('problems', 3),
#   ('presented', 3),
#   ('enjoys', 3),
#   ('capacity', 2),
#   ('teams', 2),
#   ('performance', 2),
#   ('future', 2),
#   ('baseball', 2)],
#  'Walter Creech': [('walter', 8),
#   ('sports', 7),
#   ('statistics', 4),
#   ('playing', 3),
#   ('skills', 3),
#   ('time', 3),
#   ('team', 2),
#   ('understand', 2),
#   ('analytics', 2),
#   ('decisionmaking', 2)],
#  'Emmanuel Daramola': [('emmanuel', 7),
#   ('cultures', 4),
#   ('new', 4),
#   ('different', 4),
#   ('analytics', 4),
#   ('data', 3),
#   ('skills', 2),
#   ('diverse', 2),
#   ('groups', 2),
#   ('learning', 2)],
#  'Ellen Davis': [('ellen', 7),
#   ('data', 5),
#   ('soccer', 3),
#   ('volunteer', 3),
#   ('league', 3),
#   ('analytics', 3),
#   ('unc', 2),
#   ('hill', 2),
#   ('working', 2),
#   ('premier', 2)],
#  'Supreet Sudhir Deshpande': [('supreet', 6),
#   ('data', 5),
#   ('zs', 3),
#   ('improving', 2),
#   ('associates', 2),
#   ('team', 2),
#   ('process', 2),
#   ('problems', 2),
#   ('projects', 2),
#   ('applied', 1)],
#  'Adria Dortignacq': [('adria', 6),
#   ('client', 3),
#   ('income', 2),
#   ('desire', 2),
#   ('work', 2),
#   ('internal', 2),
#   ('analysis', 2),
#   ('fund', 2),
#   ('social', 2),
#   ('bbh', 2)],
#  'Trevor Edge': [('sports', 5),
#   ('projects', 4),
#   ('trevor', 4),
#   ('career', 3),
#   ('analytics', 3),
#   ('data', 3),
#   ('baseball', 3),
#   ('team', 2),
#   ('play', 2),
#   ('state', 2)],
#  'William Elmore': [('william', 6),
#   ('love', 3),
#   ('life', 3),
#   ('problemsolving', 2),
#   ('stay', 2),
#   ('school', 2),
#   ('time', 2),
#   ('enjoys', 2),
#   ('project', 2),
#   ('way', 2)],
#  'Abla Elsergany': [('data', 7),
#   ('abla', 6),
#   ('story', 3),
#   ('analytics', 3),
#   ('worked', 2),
#   ('analyzing', 2),
#   ('meaningful', 2),
#   ('projects', 2),
#   ('sushi', 2),
#   ('level', 2)],
#  'Samantha Everett': [('psychology', 5),
#   ('samantha', 5),
#   ('statistics', 4),
#   ('undergraduate', 3),
#   ('focus', 2),
#   ('team', 2),
#   ('career', 2),
#   ('experience', 2),
#   ('samanthas', 2),
#   ('journal', 2)],
#  'Maxwell Fairbairn': [('max', 5),
#   ('jazz', 3),
#   ('summer', 2),
#   ('year', 2),
#   ('competitions', 2),
#   ('senior', 2),
#   ('technical', 2),
#   ('analytics', 2),
#   ('loves', 2),
#   ('creativity', 2)],
#  'Andrew Francis': [('andrew', 10),
#   ('biowish', 4),
#   ('environmental', 4),
#   ('research', 3),
#   ('engineering', 3),
#   ('world', 2),
#   ('communities', 2),
#   ('methane', 2),
#   ('epa', 2),
#   ('data', 2)],
#  'Christopher Goodrich': [('christopher', 6),
#   ('model', 3),
#   ('working', 3),
#   ('programming', 2),
#   ('economics', 2),
#   ('health', 2),
#   ('learning', 2),
#   ('professional', 1),
#   ('dubai', 1),
#   ('program', 1)],
#  'Thomas Gow': [('team', 3),
#   ('thomas', 3),
#   ('knotel', 2),
#   ('innovation', 2),
#   ('analytics', 2),
#   ('workforce', 2),
#   ('passion', 2),
#   ('impact', 2),
#   ('installations', 2),
#   ('small', 2)],
#  'Sydney Greer': [('sydney', 11),
#   ('analytics', 4),
#   ('research', 3),
#   ('data', 3),
#   ('university', 3),
#   ('field', 2),
#   ('led', 2),
#   ('math', 2),
#   ('internship', 2),
#   ('analysis', 2)],
#  'Sarah Grieco': [('sarah', 5),
#   ('news', 4),
#   ('career', 3),
#   ('data', 3),
#   ('working', 3),
#   ('early', 2),
#   ('people', 2),
#   ('access', 2),
#   ('information', 2),
#   ('believes', 2)],
#  'Hirsh Gupta': [('hirsh', 6),
#   ('data', 5),
#   ('experience', 3),
#   ('solving', 2),
#   ('league', 2),
#   ('pipeline', 2),
#   ('lead', 2),
#   ('identify', 2),
#   ('company', 2),
#   ('players', 2)],
#  'Savannah Hampton': [('savannah', 8),
#   ('production', 3),
#   ('career', 3),
#   ('time', 2),
#   ('analytics', 2),
#   ('model', 2),
#   ('process', 2),
#   ('france', 2),
#   ('soccer', 2),
#   ('predicted', 2)],
#  'Lance Hudson': [('time', 6),
#   ('lance', 6),
#   ('research', 5),
#   ('data', 5),
#   ('clinical', 5),
#   ('statistical', 4),
#   ('undergraduate', 2),
#   ('spent', 2),
#   ('world', 2),
#   ('trial', 2)],
#  'Nathan Jones': [('nathan', 9),
#   ('statistics', 4),
#   ('grew', 2),
#   ('speaking', 2),
#   ('public', 2),
#   ('led', 2),
#   ('joy', 2),
#   ('company', 2),
#   ('medical', 2),
#   ('questions', 2)],
#  'Shawn Kim': [('shawn', 8),
#   ('3m', 3),
#   ('sensors', 3),
#   ('technical', 2),
#   ('products', 2),
#   ('program', 2),
#   ('opportunity', 2),
#   ('analytics', 2),
#   ('different', 2),
#   ('learning', 2)],
#  'Elaine King': [('elaine', 5),
#   ('team', 4),
#   ('department', 3),
#   ('women', 3),
#   ('work', 2),
#   ('big', 2),
#   ('mentor', 2),
#   ('uncchapel', 2),
#   ('iqvia', 2),
#   ('studies', 2)],
#  'Grant King': [('grant', 6),
#   ('health', 4),
#   ('rti', 4),
#   ('economics', 4),
#   ('development', 3),
#   ('international', 3),
#   ('linguistics', 3),
#   ('research', 2),
#   ('skills', 2),
#   ('problems', 2)],
#  'Emmanuel Kinuthia': [('business', 3),
#   ('farmers', 3),
#   ('data', 2),
#   ('discussing', 2),
#   ('working', 2),
#   ('management', 1),
#   ('watching', 1),
#   ('farmerowned', 1),
#   ('sustainability', 1),
#   ('breakfast', 1)],
#  'Beruk Kiros': [('beruk', 5),
#   ('tools', 3),
#   ('research', 3),
#   ('toxicology', 3),
#   ('work', 2),
#   ('effects', 2),
#   ('national', 2),
#   ('screening', 2),
#   ('college', 2),
#   ('ntp', 2)],
#  'Taylor Kooy': [('taylor', 5),
#   ('records', 3),
#   ('project', 3),
#   ('software', 3),
#   ('agent', 3),
#   ('data', 3),
#   ('internship', 2),
#   ('team', 2),
#   ('caorle', 2),
#   ('senior', 2)],
#  'Andrea Kopaskie': [('data', 7),
#   ('andrea', 6),
#   ('water', 3),
#   ('passion', 3),
#   ('analytics', 3),
#   ('wastewater', 3),
#   ('environmental', 2),
#   ('science', 2),
#   ('surveys', 2),
#   ('utility', 2)],
#  'David Ku': [('david', 5),
#   ('optimization', 4),
#   ('time', 3),
#   ('statistics', 3),
#   ('mechanical', 3),
#   ('algorithms', 3),
#   ('data', 3),
#   ('knowledge', 3),
#   ('engineering', 3),
#   ('problems', 2)],
#  'Samuel LaFell': [('sam', 9),
#   ('abroad', 2),
#   ('team', 2),
#   ('friends', 2),
#   ('taking', 2),
#   ('studying', 2),
#   ('project', 2),
#   ('world', 2),
#   ('desire', 2),
#   ('ecuador', 2)],
#  'Laura Lancheros': [('laura', 5),
#   ('data', 4),
#   ('technical', 3),
#   ('socks', 3),
#   ('skills', 2),
#   ('amp', 2),
#   ('strong', 2),
#   ('create', 2),
#   ('did', 2),
#   ('group', 2)],
#  'Kateryna Lashko': [('kateryna', 8),
#   ('data', 4),
#   ('creative', 3),
#   ('analytics', 3),
#   ('research', 2),
#   ('favorite', 2),
#   ('places', 2),
#   ('game', 2),
#   ('include', 2),
#   ('love', 2)],
#  'Zach Lewis': [('zach', 5),
#   ('evaluation', 3),
#   ('program', 3),
#   ('students', 2),
#   ('years', 2),
#   ('led', 2),
#   ('statistics', 2),
#   ('juntos', 2),
#   ('working', 2),
#   ('coordinators', 2)],
#  'Yinxi(Evan) Li': [('evan', 9),
#   ('music', 5),
#   ('data', 4),
#   ('energy', 2),
#   ('applied', 2),
#   ('asset', 2),
#   ('housing', 2),
#   ('interdisciplinary', 2),
#   ('mexico', 2),
#   ('research', 2)],
#  'Katlyn Limer': [('data', 6),
#   ('people', 3),
#   ('katlyn', 3),
#   ('research', 3),
#   ('work', 2),
#   ('undergraduate', 2),
#   ('projects', 2),
#   ('working', 2),
#   ('health', 2),
#   ('enjoys', 2)],
#  'Kevin Lybrand': [('kevin', 6),
#   ('problems', 2),
#   ('university', 2),
#   ('impact', 2),
#   ('learning', 2),
#   ('clemson', 2),
#   ('quality', 2),
#   ('year', 2),
#   ('passion', 2),
#   ('using', 2)],
#  'Brett Lytle': [('brett', 5),
#   ('sports', 4),
#   ('data', 3),
#   ('working', 3),
#   ('school', 2),
#   ('passion', 2),
#   ('enjoys', 2),
#   ('music', 2),
#   ('travel', 2),
#   ('career', 2)],
#  'Preston Daniel MacDonald': [('preston', 8),
#   ('hivetracks', 3),
#   ('software', 3),
#   ('research', 3),
#   ('problemsolving', 2),
#   ('provided', 2),
#   ('enjoys', 2),
#   ('earned', 2),
#   ('analytics', 2),
#   ('academic', 2)],
#  'Chandni Malhotra': [('chandni', 4),
#   ('research', 4),
#   ('undergraduate', 3),
#   ('analysis', 3),
#   ('data', 3),
#   ('statistics', 2),
#   ('expertise', 2),
#   ('nc', 2),
#   ('state', 2),
#   ('multiple', 2)],
#  'Meg Malone': [('meg', 8),
#   ('media', 4),
#   ('projects', 3),
#   ('elon', 3),
#   ('data', 3),
#   ('analytics', 2),
#   ('digital', 2),
#   ('role', 2),
#   ('news', 2),
#   ('field', 2)],
#  'Michael Marchetta': [('michael', 11),
#   ('cars', 3),
#   ('team', 3),
#   ('systems', 3),
#   ('time', 3),
#   ('processes', 3),
#   ('optimizing', 2),
#   ('long', 2),
#   ('passion', 2),
#   ('tools', 2)],
#  'McKinnon Martin': [('patient', 4),
#   ('mckinnon', 4),
#   ('application', 3),
#   ('data', 3),
#   ('watsco', 2),
#   ('ups', 2),
#   ('research', 2),
#   ('company', 2),
#   ('largest', 2),
#   ('recommendations', 2)],
#  'Natalie Martin': [('natalie', 5),
#   ('skills', 3),
#   ('analytics', 3),
#   ('leadership', 3),
#   ('chapter', 2),
#   ('data', 2),
#   ('experience', 2),
#   ('financial', 2),
#   ('team', 2),
#   ('analytical', 2)],
#  'Kevin McDowell': [('kevin', 5),
#   ('analyses', 2),
#   ('baseball', 2),
#   ('financial', 2),
#   ('valuation', 2),
#   ('world', 2),
#   ('university', 2),
#   ('passion', 2),
#   ('leadership', 2),
#   ('music', 2)],
#  'Catherine McSorley': [('catherine', 4),
#   ('data', 3),
#   ('studying', 2),
#   ('carolina', 2),
#   ('design', 2),
#   ('particularly', 2),
#   ('north', 2),
#   ('projects', 2),
#   ('created', 2),
#   ('analytics', 2)],
#  'Kasia Michalska': [('work', 3),
#   ('kasia', 3),
#   ('way', 2),
#   ('analyst', 2),
#   ('board', 2),
#   ('business', 2),
#   ('spending', 2),
#   ('proven', 2),
#   ('insurance', 2),
#   ('potluck', 1)],
#  'Liesl Miranda': [('liesl', 6),
#   ('manufacturing', 3),
#   ('production', 3),
#   ('story', 3),
#   ('plastic', 3),
#   ('company', 2),
#   ('school', 2),
#   ('data', 2),
#   ('weaving', 2),
#   ('analytics', 2)],
#  'Will Misenheimer': [('data', 6),
#   ('analytics', 3),
#   ('project', 3),
#   ('sentryone', 2),
#   ('disc', 2),
#   ('science', 2),
#   ('microsoft', 2),
#   ('model', 2),
#   ('learning', 2),
#   ('scoring', 2)],
#  'Iqra Munawar': [('math', 3),
#   ('time', 3),
#   ('world', 3),
#   ('iqras', 3),
#   ('knowledge', 2),
#   ('tutoring', 2),
#   ('data', 2),
#   ('position', 2),
#   ('people', 2),
#   ('learned', 2)],
#  'Rachel Nagley': [('rachel', 6),
#   ('pantry', 3),
#   ('world', 3),
#   ('food', 3),
#   ('new', 3),
#   ('make', 2),
#   ('team', 2),
#   ('apply', 2),
#   ('skills', 2),
#   ('optimization', 2)],
#  'Ragi Nayak': [('data', 7),
#   ('ragi', 6),
#   ('special', 3),
#   ('analytics', 3),
#   ('olympics', 3),
#   ('undergraduate', 2),
#   ('learn', 2),
#   ('need', 2),
#   ('better', 2),
#   ('love', 2)],
#  'Travis Noftle': [('data', 4),
#   ('enjoys', 3),
#   ('experience', 3),
#   ('travis', 2),
#   ('teams', 2),
#   ('passions', 2),
#   ('creative', 2),
#   ('various', 2),
#   ('effective', 2),
#   ('reporting', 2)],
#  'Urbain Nounagnon': [('urbain', 8),
#   ('quality', 6),
#   ('analytics', 3),
#   ('work', 3),
#   ('challenges', 3),
#   ('led', 2),
#   ('american', 2),
#   ('effective', 2),
#   ('coordination', 2),
#   ('columbus', 2)],
#  'Krishna Patel': [('krishna', 7),
#   ('analytics', 5),
#   ('trip', 2),
#   ('financial', 2),
#   ('students', 2),
#   ('careers', 2),
#   ('maria', 2),
#   ('time', 2),
#   ('new', 2),
#   ('discover', 2)],
#  'Payal Patel': [('data', 8),
#   ('payal', 6),
#   ('stem', 4),
#   ('analyst', 3),
#   ('new', 3),
#   ('women', 2),
#   ('role', 2),
#   ('market', 2),
#   ('different', 2),
#   ('support', 2)],
#  'Samir Patel': [('samir', 7),
#   ('statistics', 3),
#   ('soccer', 3),
#   ('passion', 2),
#   ('enjoys', 2),
#   ('recreate', 2),
#   ('research', 2),
#   ('running', 2),
#   ('teaching', 2),
#   ('school', 2)],
#  'Urmila Patil': [('data', 7),
#   ('urmila', 5),
#   ('analytics', 4),
#   ('business', 4),
#   ('experience', 3),
#   ('different', 3),
#   ('problems', 3),
#   ('health', 2),
#   ('using', 2),
#   ('problemsolving', 2)],
#  'Jackson Perry': [('jackson', 7),
#   ('team', 5),
#   ('project', 3),
#   ('years', 2),
#   ('contributed', 2),
#   ('lifestyle', 2),
#   ('skills', 2),
#   ('earned', 2),
#   ('model', 2),
#   ('swim', 2)],
#  'Rachel Powell': [('rachel', 9),
#   ('data', 4),
#   ('time', 3),
#   ('research', 3),
#   ('best', 3),
#   ('analytics', 3),
#   ('new', 3),
#   ('thai', 2),
#   ('problemsolving', 2),
#   ('auburn', 2)],
#  'Alexander Preiss': [('sandy', 8),
#   ('data', 7),
#   ('work', 4),
#   ('complex', 3),
#   ('acs', 3),
#   ('ipas', 2),
#   ('hpv', 2),
#   ('systems', 2),
#   ('programs', 2),
#   ('database', 2)],
#  'Sunny\tQin': [('sunny', 8),
#   ('business', 6),
#   ('new', 5),
#   ('membership', 3),
#   ('marketing', 3),
#   ('data', 3),
#   ('student', 2),
#   ('senior', 2),
#   ('reports', 2),
#   ('passion', 2)],
#  'Lahari Revuri': [('lahari', 8),
#   ('research', 5),
#   ('data', 5),
#   ('state', 3),
#   ('undergraduate', 3),
#   ('carolina', 2),
#   ('models', 2),
#   ('presented', 2),
#   ('north', 2),
#   ('lab', 2)],
#  'Jonathan Rice': [('jonathan', 8),
#   ('work', 5),
#   ('team', 4),
#   ('projects', 3),
#   ('science', 2),
#   ('graduate', 2),
#   ('research', 2),
#   ('dedication', 2),
#   ('continues', 2),
#   ('merced', 2)],
#  'Benjamin Roberts': [('benjamin', 8),
#   ('spanish', 4),
#   ('political', 3),
#   ('students', 2),
#   ('madrid', 2),
#   ('using', 2),
#   ('experience', 2),
#   ('economics', 2),
#   ('economic', 2),
#   ('exploring', 2)],
#  'Basil Rodts': [('basil', 5),
#   ('company', 3),
#   ('life', 3),
#   ('industry', 3),
#   ('development', 2),
#   ('football', 2),
#   ('uncchapel', 2),
#   ('data', 2),
#   ('family', 2),
#   ('hill', 2)],
#  'Kyrsten Rudock': [('kyrsten', 5),
#   ('analytics', 4),
#   ('product', 3),
#   ('data', 3),
#   ('award', 2),
#   ('perfect', 2),
#   ('sides', 2),
#   ('experience', 2),
#   ('people', 2),
#   ('blend', 2)],
#  'Burton Scott Rudolph\n': [('burton', 5),
#   ('decisionmaking', 2),
#   ('data', 2),
#   ('analytical', 2),
#   ('impact', 2),
#   ('morgan', 2),
#   ('future', 2),
#   ('skills', 2),
#   ('jp', 2),
#   ('work', 2)],
#  'Charlie Ruff\n': [('charlie', 10),
#   ('analytics', 7),
#   ('friends', 5),
#   ('team', 5),
#   ('center', 4),
#   ('data', 4),
#   ('sports', 4),
#   ('model', 3),
#   ('university', 3),
#   ('analytical', 3)],
#  'Sameen Salam': [('sameen', 6),
#   ('music', 5),
#   ('time', 2),
#   ('ran', 2),
#   ('biology', 2),
#   ('data', 2),
#   ('numbers', 2),
#   ('variety', 1),
#   ('early', 1),
#   ('age', 1)],
#  'Samantha Sassorossi': [('samantha', 9),
#   ('data', 5),
#   ('business', 4),
#   ('science', 3),
#   ('time', 2),
#   ('role', 2),
#   ('create', 2),
#   ('technical', 2),
#   ('program', 2),
#   ('seven', 2)],
#  'Cassidy Sater': [('cassidy', 4),
#   ('different', 2),
#   ('students', 2),
#   ('visualization', 2),
#   ('eye', 2),
#   ('class', 2),
#   ('drawing', 2),
#   ('statistics', 2),
#   ('time', 2),
#   ('rates', 2)],
#  'Noah Woessner Sayre': [('noah', 9),
#   ('team', 4),
#   ('time', 2),
#   ('school', 2),
#   ('club', 2),
#   ('values', 2),
#   ('data', 2),
#   ('yearround', 2),
#   ('hill', 2),
#   ('swim', 2)],
#  'Sam Scarpino': [('sam', 5),
#   ('analytics', 3),
#   ('passion', 2),
#   ('success', 2),
#   ('pursue', 2),
#   ('school', 2),
#   ('music', 2),
#   ('undergraduate', 2),
#   ('statistics', 2),
#   ('techniques', 2)],
#  'Austin Seals': [('austin', 9),
#   ('data', 6),
#   ('soccer', 5),
#   ('research', 4),
#   ('science', 3),
#   ('music', 3),
#   ('terrorist', 2),
#   ('loves', 2),
#   ('university', 2),
#   ('world', 2)],
#  'Keyur Shah': [('keyur', 3),
#   ('techniques', 3),
#   ('statistical', 3),
#   ('master', 3),
#   ('new', 3),
#   ('analysis', 3),
#   ('cricket', 3),
#   ('experience', 2),
#   ('statistics', 2),
#   ('went', 2)],
#  'Sufyan Shahin': [('sufyan', 6),
#   ('team', 3),
#   ('past', 3),
#   ('leadership', 3),
#   ('skills', 2),
#   ('years', 2),
#   ('coaching', 2),
#   ('build', 2),
#   ('communicate', 2),
#   ('state', 2)],
#  'Mehak Shamdasani': [('mehak', 6),
#   ('technical', 4),
#   ('worked', 3),
#   ('skills', 3),
#   ('coding', 3),
#   ('methodical', 2),
#   ('algorithm', 2),
#   ('team', 2),
#   ('explored', 2),
#   ('understand', 2)],
#  'Stephen Slogar\n': [('stephen', 9),
#   ('theory', 3),
#   ('math', 3),
#   ('statistics', 3),
#   ('modeling', 2),
#   ('got', 2),
#   ('fidelity', 2),
#   ('using', 2),
#   ('running', 2),
#   ('software', 2)],
#  'Jiin Son': [('analytics', 6),
#   ('data', 6),
#   ('jiin', 5),
#   ('using', 3),
#   ('nfc', 3),
#   ('chip', 3),
#   ('sales', 3),
#   ('ring', 2),
#   ('clothing', 2),
#   ('mental', 2)],
#  'Paige Spell': [('paige', 4),
#   ('data', 2),
#   ('degree', 2),
#   ('project', 2),
#   ('afraid', 2),
#   ('wanted', 2),
#   ('make', 2),
#   ('took', 2),
#   ('fail', 2),
#   ('passion', 2)],
#  'Nick Sterling': [('nick', 7),
#   ('market', 3),
#   ('project', 3),
#   ('physics', 3),
#   ('closely', 2),
#   ('years', 2),
#   ('housing', 2),
#   ('analytics', 2),
#   ('problems', 2),
#   ('old', 2)],
#  'Ben Sullivan': [('ben', 5),
#   ('challenge', 3),
#   ('analytics', 3),
#   ('using', 2),
#   ('local', 2),
#   ('academic', 2),
#   ('business', 2),
#   ('undergraduate', 2),
#   ('time', 2),
#   ('sales', 2)],
#  'Heqing Sun': [('heqing', 7),
#   ('data', 6),
#   ('analytics', 3),
#   ('chemistry', 3),
#   ('graduate', 2),
#   ('day', 2),
#   ('quickly', 2),
#   ('food', 2),
#   ('uncchapel', 2),
#   ('make', 2)],
#  'Yao Sun ': [('yao', 8),
#   ('data', 4),
#   ('research', 3),
#   ('business', 3),
#   ('international', 2),
#   ('thousand', 2),
#   ('analytical', 2),
#   ('project', 2),
#   ('skills', 2),
#   ('chinese', 2)],
#  'Shannon Tart': [('data', 6),
#   ('shannon', 5),
#   ('used', 3),
#   ('love', 3),
#   ('far', 3),
#   ('recruitment', 3),
#   ('pgi', 2),
#   ('creativity', 2),
#   ('accessory', 2),
#   ('materials', 2)],
#  'Reema Thakkar': [('reema', 5),
#   ('time', 3),
#   ('dance', 3),
#   ('abilities', 3),
#   ('data', 2),
#   ('research', 2),
#   ('indian', 2),
#   ('analytical', 2),
#   ('provide', 2),
#   ('students', 2)],
#  'Chelsea Thomas': [('data', 5),
#   ('chelsea', 3),
#   ('future', 3),
#   ('appreciation', 2),
#   ('prediction', 2),
#   ('time', 2),
#   ('sales', 2),
#   ('giving', 2),
#   ('enjoys', 2),
#   ('inefficiencies', 2)],
#  'Jason Thompson\n': [('jason', 7),
#   ('basketball', 3),
#   ('younger', 3),
#   ('analytics', 3),
#   ('sports', 3),
#   ('department', 2),
#   ('science', 2),
#   ('pursuing', 2),
#   ('led', 2),
#   ('nc', 2)],
#  'Wesley Thompson': [('wesley', 6),
#   ('team', 4),
#   ('data', 3),
#   ('office', 2),
#   ('vcoe', 2),
#   ('best', 2),
#   ('differentiators', 2),
#   ('teams', 2),
#   ('education', 2),
#   ('way', 2)],
#  'Cathy Tran': [('cathy', 7),
#   ('employee', 3),
#   ('college', 3),
#   ('market', 3),
#   ('team', 2),
#   ('employment', 2),
#   ('working', 2),
#   ('capital', 2),
#   ('internships', 2),
#   ('professional', 2)],
#  'Khoi Minh Tran': [('khoi', 7),
#   ('taught', 3),
#   ('business', 3),
#   ('skills', 2),
#   ('innovation', 2),
#   ('story', 2),
#   ('crater', 2),
#   ('learning', 2),
#   ('life', 2),
#   ('people', 2)],
#  'Faith Turner': [('faith', 7),
#   ('business', 3),
#   ('love', 3),
#   ('coding', 2),
#   ('enjoys', 2),
#   ('understand', 2),
#   ('management', 2),
#   ('customer', 2),
#   ('data', 2),
#   ('dashboard', 2)],
#  'Travis M. Walker': [('mission', 3),
#   ('travis', 3),
#   ('led', 3),
#   ('success', 2),
#   ('solutions', 2),
#   ('personal', 2),
#   ('leadership', 2),
#   ('navy', 2),
#   ('earned', 2),
#   ('senior', 2)],
#  'Meghan Weber': [('meghan', 6),
#   ('air', 5),
#   ('force', 4),
#   ('work', 4),
#   ('impact', 3),
#   ('machine', 2),
#   ('laboratory', 2),
#   ('positive', 2),
#   ('school', 2),
#   ('military', 2)],
#  'Ryan Weisner': [('ryan', 3),
#   ('music', 3),
#   ('difference', 3),
#   ('impact', 2),
#   ('year', 2),
#   ('chapter', 2),
#   ('free', 2),
#   ('analyze', 2),
#   ('education', 2),
#   ('discovered', 2)],
#  'Samantha  Widman': [('samantha', 5),
#   ('data', 4),
#   ('sports', 3),
#   ('skills', 3),
#   ('involved', 2),
#   ('including', 2),
#   ('team', 2),
#   ('college', 2),
#   ('school', 2),
#   ('learn', 2)],
#  'Sarah Wotus ': [('sarah', 7),
#   ('health', 5),
#   ('data', 3),
#   ('studies', 3),
#   ('water', 3),
#   ('analysis', 2),
#   ('internship', 2),
#   ('parks', 2),
#   ('city', 2),
#   ('public', 2)],
#  'Lu Wu': [('lu', 6),
#   ('student', 3),
#   ('communication', 3),
#   ('program', 3),
#   ('group', 2),
#   ('team', 2),
#   ('department', 2),
#   ('work', 2),
#   ('local', 2),
#   ('social', 2)],
#  'Chesaney Wyse ': [('chesaney', 5),
#   ('data', 3),
#   ('football', 2),
#   ('explore', 2),
#   ('academic', 2),
#   ('limits', 2),
#   ('undergraduate', 2),
#   ('nanodegree', 1),
#   ('clients', 1),
#   ('like', 1)],
#  'Sharon Yao': [('sharon', 7),
#   ('data', 5),
#   ('research', 2),
#   ('analytics', 2),
#   ('findings', 2),
#   ('company', 2),
#   ('detective', 2),
#   ('programs', 2),
#   ('analysis', 2),
#   ('student', 2)],
#  'Michael Zabawa': [('michael', 6),
#   ('data', 3),
#   ('future', 2),
#   ('course', 2),
#   ('knowledge', 2),
#   ('worked', 2),
#   ('outdoor', 2),
#   ('family', 2),
#   ('unique', 2),
#   ('mountains', 2)]}

# %%
# make the top 10 words said by each person to a dict
top=[]
for name, top_words in top_dict.items():
    top.append({'name': name, 'words': ', '.join([word for word, count in top_words[0:9]])})

# %%
top=pd.DataFrame(top)

# %%
top.head()
# Out:
#              name                                              words
# 0    Shiraz Ahmed  data, shiraz, foreign, work, middle, analytics...
# 1    Emily Ammons  emily, research, community, native, study, gra...
# 2  David Andexler  david, time, student, organizations, marketing...
# 3   Ryan Ankersen  ryan, new, challenges, members, learn, event, ...
# 4    Rivers Baker  rivers, business, analytics, data, development...

# %%
display(top[top.name=='Lu Wu'])
# Out:
#       name                                              words
# 114  Lu Wu  lu, student, communication, program, group, te...

# %% [markdown]
# ## Identify the non-zero items in the document-term matrix

# %%
# Identify the non-zero items in the document-term matrix, meaning that the word occurs at least once
unique_list = []
for name in data.columns:
    uniques = data[name].nonzero()[0].size
    unique_list.append(uniques)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   after removing the cwd from sys.path.

# %%
#unique_list

# %%
a
# Out:
# Index(['Shiraz Ahmed', 'Emily Ammons', 'David Andexler', 'Ryan Ankersen',
#        'Rivers Baker', 'Robert Bayer', 'Alison Berger', 'Marshall Bradley',
#        'Price Burnett', 'Jackson Cabell',
#        ...
#        'Faith Turner', 'Travis M. Walker', 'Meghan Weber', 'Ryan Weisner',
#        'Samantha  Widman', 'Sarah Wotus ', 'Lu Wu', 'Chesaney Wyse ',
#        'Sharon Yao', 'Michael Zabawa'],
#       dtype='object', name='Name', length=118)

# %%
# Create a new dataframe that contains this unique word count
#a=profile.name.unique()
data_words = pd.DataFrame(list(zip(a, unique_list)), columns=['name', 'unique_words'])
data_unique_sort = data_words.sort_values(by='unique_words', ascending=False)
#data_unique_sort

# %%
data_unique_sort.to_csv(r'uniquewords_2.csv')

# %% [markdown]
# # lookup

# %%
profile_n=profile[(profile['International']==0) & (profile['Gender']=='M' )]

# %%
profile_n.index
# Out:
# Index(['Shiraz Ahmed', 'David Andexler', 'Ryan Ankersen', 'Robert Bayer',
#        'Marshall Bradley', 'Price Burnett', 'Jackson Cabell',
#        'Patrick Campbell', 'Dominick Carbone', 'Kyle Clapper', 'Grant Clark',
#        'Jess Conner', 'Walter Creech', 'Emmanuel Daramola', 'Trevor Edge',
#        'William Elmore', 'Maxwell Fairbairn', 'Andrew Francis',
#        'Christopher Goodrich', 'Thomas Gow', 'Hirsh Gupta', 'Lance Hudson',
#        'Nathan Jones', 'Shawn Kim', 'Grant King', 'Beruk Kiros', 'Taylor Kooy',
#        'Samuel LaFell', 'Zach Lewis', 'Kevin Lybrand', 'Brett Lytle',
#        'Preston Daniel MacDonald', 'Michael Marchetta', 'McKinnon Martin',
#        'Kevin McDowell', 'Will Misenheimer', 'Travis Noftle',
#        'Urbain Nounagnon', 'Samir Patel', 'Jackson Perry', 'Alexander Preiss',
#        'Jonathan Rice', 'Benjamin Roberts', 'Basil Rodts',
#        'Burton Scott Rudolph\n', 'Charlie Ruff\n', 'Sameen Salam',
#        'Noah Woessner Sayre', 'Sam Scarpino', 'Austin Seals', 'Sufyan Shahin',
#        'Stephen Slogar\n', 'Nick Sterling', 'Ben Sullivan', 'Jason Thompson\n',
#        'Wesley Thompson', 'Travis M. Walker', 'Ryan Weisner',
#        'Michael Zabawa'],
#       dtype='object', name='Name')

# %%
ss=['Ryan Ankersen', 'Robert Bayer','Price Burnett', 'Jackson Cabell',
       'Patrick Campbell','Kyle Clapper', 'Grant Clark',
       'Jess Conner', 'Walter Creech','Trevor Edge',
       'William Elmore', 'Maxwell Fairbairn', 'Thomas Gow','Lance Hudson', 'Zach Lewis', 'Kevin Lybrand', 'Brett Lytle',
       'Preston Daniel MacDonald', 'Michael Marchetta', 'McKinnon Martin',
       'Kevin McDowell', 'Will Misenheimer', 'Travis Noftle', 'Jackson Perry','Benjamin Roberts', 'Basil Rodts',
       'Burton Scott Rudolph', 'Charlie Ruff','Sam Scarpino',]

# %%
ss=profile_n[profile_n.index.isin(ss)]

# %%
profile_n.head()
# Out:
#                  Gender              All But Last Paragraph (professional)  \
# Name
# Shiraz Ahmed          M  Known at home for asking many questions, Shira...
# David Andexler        M  From an early age, David capitalized on his in...
# Ryan Ankersen         M  Ryan is the perfect combination of his highly ...
# Robert Bayer          M  Robert’s work ethic and efficient time managem...
# Marshall Bradley      M  From the time he was young, Marshall has held ...
#
#                                           Last Paragraph (personal) Cohort  \
# Name
# Shiraz Ahmed      When not programming or analyzing data, Shiraz...      o
# David Andexler    David has a passion for analysis and for gener...      o
# Ryan Ankersen     In his leisure time, Ryan enjoys any hobby tha...      o
# Robert Bayer      When Robert is not working, he tries to take a...      o
# Marshall Bradley  Professionally, Marshall enjoys learning about...      o
#
#                   International  \
# Name
# Shiraz Ahmed                0.0
# David Andexler              0.0
# Ryan Ankersen               0.0
# Robert Bayer                0.0
# Marshall Bradley            0.0
#
#                                                                full
# Name
# Shiraz Ahmed      Known at home for asking many questions, Shira...
# David Andexler    From an early age, David capitalized on his in...
# Ryan Ankersen     Ryan is the perfect combination of his highly ...
# Robert Bayer      Robert’s work ethic and efficient time managem...
# Marshall Bradley  From the time he was young, Marshall has held ...

# %%
ss['full']
# Out:
# Name
# Ryan Ankersen               Ryan is the perfect combination of his highly ...
# Robert Bayer                Robert’s work ethic and efficient time managem...
# Price Burnett               Price has always been a meticulous planner, ta...
# Jackson Cabell              The youngest of three, Jackson has always been...
# Patrick Campbell            Leveraging over seven years of experience in t...
# Kyle Clapper                Kyle discovered his eye for process improvemen...
# Grant Clark                 Growing up, Grant was always fascinated with s...
# Jess Conner                 Jess is an avid learner who enjoys engaging wi...
# Walter Creech               Throughout all the seasons, Walter was constan...
# Trevor Edge                 Through his love for sports, specifically base...
# William Elmore              William’s love for solving complex problems ha...
# Maxwell Fairbairn           While training as a jazz pianist during his un...
# Thomas Gow                  Strategy and innovation became a passion of Th...
# Lance Hudson                Lance’s interests in the world of athletics pa...
# Grant King                  Grant discovered analytics through a desire to...
# Samuel LaFell               Analyzing baseball card statistics as a kid to...
# Zach Lewis                  Zach’s determination has equipped him with the...
# Kevin Lybrand               Kevin is a curious person who has always searc...
# Brett Lytle                 The product of a small town outside of Ashevil...
# Preston Daniel MacDonald    From fighting a structure fire at 4:00 AM to c...
# Michael Marchetta           For as long as Michael can remember, he has ha...
# McKinnon Martin             McKinnon spent the previous two years designin...
# Kevin McDowell              Kevin’s love of analytics began at an early ag...
# Will Misenheimer            Bridging data science with his personal intere...
# Travis Noftle               Having\talmost\ta\tdecade\tof\texperience\tin\...
# Jackson Perry               Team\t is\t everything\t to\t Jackson.\t Over\...
# Benjamin Roberts            Growing        up        in        a        sm...
# Basil Rodts                 Basil\twill\t“try\tanything\tonce.”\tThis\tlif...
# Sam Scarpino                Before\tarriving\tin\tthe\tfield\tof\tanalytic...
# Ben Sullivan                Ben found an interest in analytics during his ...
# Michael Zabawa              Believing that knowledge backed with data is m...
# Name: full, dtype: object
